# %% [markdown]
# # This is a header

# %% [markdown]
# # This is a header

# %% [markdown]
# # This is a header

# %%
import matplotlib.pyplot as plt
x = linspace(0, 5, 10)
y = x ** 2

fig1 = figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')

# %%
import matplotlib.pyplot as plt
x = linspace(0, 5, 10)
y = x * 2

fig1 = figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')

# %%
fig1

# %%
fig1

# %%
fig1

# %%
file = open('test.txt', 'w')
file.write("test")

file_2 =open('test.txt')
print file_2.read()
# Out:
# test

# %%
file = open('test.txt', 'w')
file.write("test")

file_2 =open('test.txt')
print file_2.read()
# Out:
# test

# %%
file = open('test.txt', 'w')
file.write("test")

file_2 =open('test.txt')
print file_2.read()
# Out:
# test

# %%
def test():
    return 4
test()
# Out:
# 4

# %%
def test():
    return 4
test()
# Out:
# 4

# %%
def test():
    return 4
test()
# Out:
# 4

# %%
def test2(x):
    return x**2
test2(2)
# Out:
# 4

# %%
def test2(x):
    return x**2
test2(2)
# Out:
# 4

# %%
def test2(x):
    return x**2
test2(2)
# Out:
# 4

# %%
class testClass(object):
    def __init__(self, y):
        self.x = 10
        self.y = y

testClass(12)

# %%
class testClass(object):
    def __init__(self, y):
        self.x = 10
        self.y = y

testClass(12)

# %%
class testClass(object):
    def __init__(self, y):
        self.x = 10
        self.y = y

testClass(12)

# %%
def fib(n):
    if n < 0:
        return -1
    elif n == 0: 
        return 0
    elif n == 1:
        return 1
    else:
        return (fib(n-1)+fib(n-2))

print "fibbonnaci of -1 is: " + str(fib(-1))
print "fibbonnaci of 0 is: " + str(fib(0))
print "fibbonnaci of 2 is: " + str(fib(2))
print "fibbonnaci of 10 is: " + str(fib(10))
# Out:
# fibbonnaci of -1 is: -1
# fibbonnaci of 0 is: 0
# fibbonnaci of 2 is: 1
# fibbonnaci of 10 is: 55

# %%
def fib(n):
    if n < 0:
        return -1
    elif n == 0: 
        return 0
    elif n == 1:
        return 1
    else:
        return (fib(n-1)+fib(n-2))

print "fibbonnaci of -1 is: " + str(fib(-1))
print "fibbonnaci of 0 is: " + str(fib(0))
print "fibbonnaci of 2 is: " + str(fib(2))
print "fibbonnaci of 10 is: " + str(fib(10))
# Out:
# fibbonnaci of -1 is: -1
# fibbonnaci of 0 is: 0
# fibbonnaci of 2 is: 1
# fibbonnaci of 10 is: 55

# %%
def fib(n):
    if n < 0:
        return -1
    elif n == 0: 
        return 0
    elif n == 1:
        return 1
    else:
        return (fib(n-1)+fib(n-2))

print "fibbonnaci of -1 is: " + str(fib(-1))
print "fibbonnaci of 0 is: " + str(fib(0))
print "fibbonnaci of 2 is: " + str(fib(2))
print "fibbonnaci of 10 is: " + str(fib(10))
# Out:
# fibbonnaci of -1 is: -1
# fibbonnaci of 0 is: 0
# fibbonnaci of 2 is: 1
# fibbonnaci of 10 is: 55

# %%
a = []
b = []

for z in range(0, 20):
    a.append(random.randint(0,50))
    b.append(random.randint(0,100))
print a;
print b;

fig2 = figure()
plot(a, b, "bo")
xlabel('a-randoms')
ylabel('b-randoms')
title('random plot')
# Out:
# [40, 45, 29, 42, 12, 4, 13, 23, 44, 4, 15, 6, 44, 6, 44, 19, 4, 6, 23, 0]
# [92, 58, 83, 63, 75, 86, 41, 20, 28, 52, 86, 34, 69, 82, 38, 60, 82, 45, 78, 71]

# %%
a = []
b = []

for z in range(0, 20):
    a.append(random.randint(0,50))
    b.append(random.randint(0,100))
print a;
print b;

fig2 = figure()
plot(a, b, "bo")
xlabel('a-randoms')
ylabel('b-randoms')
title('random plot')
# Out:
# [40, 45, 29, 42, 12, 4, 13, 23, 44, 4, 15, 6, 44, 6, 44, 19, 4, 6, 23, 0]
# [92, 58, 83, 63, 75, 86, 41, 20, 28, 52, 86, 34, 69, 82, 38, 60, 82, 45, 78, 71]

# %%
a = []
b = []

for z in range(0, 20):
    a.append(random.randint(0,50))
    b.append(random.randint(0,100))
print a;
print b;

fig2 = figure()
plot(a, b, "bo")
xlabel('a-randoms')
ylabel('b-randoms')
title('random plot')
# Out:
# [40, 45, 29, 42, 12, 4, 13, 23, 44, 4, 15, 6, 44, 6, 44, 19, 4, 6, 23, 0]
# [92, 58, 83, 63, 75, 86, 41, 20, 28, 52, 86, 34, 69, 82, 38, 60, 82, 45, 78, 71]

# %%
fig2

# %%
fig2

# %%
fig2

# %%
import matplotlib.gridspec as gridspec


fig = plt.figure()

gs = gridspec.GridSpec(2, 3, height_ratios=[2,1], width_ratios=[1,2,1])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec


fig = plt.figure()

gs = gridspec.GridSpec(2, 3, height_ratios=[2,1], width_ratios=[1,2,1])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec


fig = plt.figure()

gs = gridspec.GridSpec(2, 3, height_ratios=[2,1], width_ratios=[1,2,1])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
fig

# %%
fig

# %%
fig

# %%
fig3 = figure()
x = linspace(0, 2*pi, 42)
f1 = 5 * sin(x)
f2 = 2 * sin(2*x)
f3 = 1 * sin(3*x)
plot(x, f1)
plot(x, f2, 'ro')
plot(x, f3, 'g--')
# Out:
# []

# %%
fig3 = figure()
x = linspace(0, 2*pi, 42)
f1 = 5 * sin(x)
f2 = 2 * sin(2*x)
f3 = 1 * sin(3*x)
plot(x, f1)
plot(x, f2, 'ro')
plot(x, f3, 'g--')
# Out:
# []

# %%
fig3 = figure()
x = linspace(0, 2*pi, 42)
f1 = 5 * sin(x)
f2 = 2 * sin(2*x)
f3 = 1 * sin(3*x)
plot(x, f1)
plot(x, f2, 'ro')
plot(x, f3, 'g--')
# Out:
# []

# %%
fig3

# %%
fig3

# %%
fig3

# %% [markdown]
# Test mark down

# %% [raw]
# Just some raw text

# %% [markdown]
# ###### Header 6

# %% [markdown]
# ######

# %% [markdown]
# ######
